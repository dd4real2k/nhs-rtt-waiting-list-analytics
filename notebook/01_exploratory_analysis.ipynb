# %%
import os
import pandas as pd

df = pd.read_excel("../data/raw/rtt_incomplete_pathways.xlsx")

df.head()
# Out:
#    Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0         NaN     Title:          Referral to Treatment (RTT) Waiting Times
# 1         NaN   Summary:  Monthly Referral to Treatment (RTT) waiting ti...
# 2         NaN        NaN                                                NaN
# 3         NaN    Period:                                         March 2026
# 4         NaN    Source:           NHS England: monthly RTT data collection
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 110  \
# 0        NaN  ...          NaN
# 1        NaN  ...          NaN
# 2        NaN  ...          NaN
# 3        NaN  ...          NaN
# 4        NaN  ...          NaN
#
#                                         Unnamed: 111 Unnamed: 112  \
# 0  [The '+' button above reveals the full weekly ...          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#   Unnamed: 113 Unnamed: 114 Unnamed: 115 Unnamed: 116 Unnamed: 117  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 118 Unnamed: 119
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 120 columns]

# %%
print(df.shape)
print(df.columns.to_flat_index())
# Out:
# (3613, 120)
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112', 'Unnamed: 113',
#        'Unnamed: 114', 'Unnamed: 115', 'Unnamed: 116', 'Unnamed: 117',
#        'Unnamed: 118', 'Unnamed: 119'],
#       dtype='object', length=120)

# %%
df = pd.read_excel(
    "../data/raw/rtt_incomplete_pathways.xlsx",
    header=13
)

df = df.dropna(axis=1, how="all")

# %%
keep_cols = [
    "Region Code",
    "Provider Code",
    "Provider Name",
    "Treatment Function Code",
    "Treatment Function",
    "Total number of incomplete pathways",
    "Total within 18 weeks",
    "% within 18 weeks",
    "Average (median) waiting time (in weeks)",
    "92nd percentile waiting time (in weeks)",
    "Total 52 plus weeks",
    "Total 65 plus weeks",
    "Total 78 plus weeks",
    "% 52 plus weeks"
]

rtt = df[keep_cols].copy()

# %%
rtt["reporting_month"] = "2026-03"

# %%
rtt.shape
# Out:
# (3600, 15)
